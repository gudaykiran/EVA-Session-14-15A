# %% [markdown]
# # Mounting the Gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Importing the Necessary Packages

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %% [markdown]
# # Creating a Directory to save generated images

# %%
# !mkdir OverlayDir
# Out:
# mkdir: cannot create directory ‘OverlayDir’: File exists

# %%
# %cd OverlayDir
# !mkdir BgFg
# !mkdir BgFgMask
# Out:
# /content/OverlayDir
# mkdir: cannot create directory ‘BgFg’: File exists
# mkdir: cannot create directory ‘BgFgMask’: File exists

# %%
# %cd ..
# Out:
# /content

# %%
path = '/content/gdrive/My Drive/EVA4/fg_bg Images/'
start1 = 1 # -----------------------Choose Image numbers-----# for Dataset Creation part 1 80K
black = np.zeros((224,224))

for i in range(1,101): #1 Background Images -------------

    bg = Image.open(f'{path}/BackgroundMall/bg{str(i)}.jpg')

    for j in  range(1,21): #1 Foreground Images------- Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}/ForegroundPerson/fg{str(j)}.png')
      mask = Image.open(f'{path}/Mask/m{str(j)}.png').convert('1')

      for k in range(1,21): #Randomly Placing 20 times--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        bg1.paste(fg1,(r1,r2),fg1) 
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/OverlayDir/BgFg/bgfg{str(start1)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start1)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start1+=1

        bg2.save(f"/content/OverlayDir/BgFg/bgfg{str(start1)}.jpg",optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start1)}.jpg",optimize=True, quality=30)#------------Create Different folder-----------

        start1+=1
        print(start1)

path = '/content/gdrive/My Drive/EVA4/fg_bg Images/'
start2 = start1 # Dataset Creation part 2 160K
black = np.zeros((224,224))

for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}/BackgroundMall/bg{str(i)}.jpg')

    for j in  range(21,41): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}/ForegroundPerson/fg{str(j)}.png')
      mask = Image.open(f'{path}/Mask/m{str(j)}.png').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

      
        bg1.paste(fg1,(r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/OverlayDir/BgFg/bgfg{str(start2)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start2)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start2+=1

        bg2.save(f"/content/OverlayDir/BgFg/bgfg{str(start2)}.jpg",optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start2)}.jpg",optimize=True, quality=30)#------------Create Different folder-----------

        start2+=1
        print(start2)

path = '/content/gdrive/My Drive/EVA4/fg_bg Images/'
start3 = start2 # Dataset Creation Part 3 240K
black = np.zeros((224,224))

for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}/BackgroundMall/bg{str(i)}.jpg')

    for j in  range(41,61): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}/ForegroundPerson/fg{str(j)}.png')
      mask = Image.open(f'{path}/Mask/m{str(j)}.png').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        
      
        bg1.paste(fg1,(r1,r2),fg1) 
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/OverlayDir/BgFg/bgfg{str(start3)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start3)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start3+=1

        bg2.save(f"/content/OverlayDir/BgFg/bgfg{str(start3)}.jpg",optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start3)}.jpg",optimize=True, quality=30)#------------Create Different folder-----------

        start3+=1
        print(start3)

path = '/content/gdrive/My Drive/EVA4/fg_bg Images/'
start4 = start3 # Dataset Creation Part 4 320K
black = np.zeros((224,224))

for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}/BackgroundMall/bg{str(i)}.jpg')

    for j in  range(61,81): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}/ForegroundPerson/fg{str(j)}.png')
      mask = Image.open(f'{path}/Mask/m{str(j)}.png').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        bg1.paste(fg1,(r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1) 
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/OverlayDir/BgFg/bgfg{str(start4)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start4)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start4+=1

        bg2.save(f"/content/OverlayDir/BgFg/bgfg{str(start4)}.jpg",optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start4)}.jpg",optimize=True, quality=30)#------------Create Different folder-----------

        start4+=1
        print(start4)


path = '/content/gdrive/My Drive/EVA4/fg_bg Images/'
start5 = start4 #Dataset Creation Part 5 - 400K
black = np.zeros((224,224))

for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}/BackgroundMall/bg{str(i)}.jpg')

    for j in  range(81,101): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}/ForegroundPerson/fg{str(j)}.png')
      mask = Image.open(f'{path}/Mask/m{str(j)}.png').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask    
       
        bg1.paste(fg1,(r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1) 
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/OverlayDir/BgFg/bgfg{str(start5)}.jpg",optimize=True, quality=30)#------------Create Different folder-------------
        black_img1.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start5)}.jpg",optimize=True, quality=30) #-------------Create Different Path folder----

        start5+=1

        bg2.save(f"/content/OverlayDir/BgFg/bgfg{str(start5)}.jpg",optimize=True, quality=30)#------------Create Different folder---------------
        black_img2.save(f"/content/OverlayDir/BgFgMask/bgfgmask{str(start5)}.jpg",optimize=True, quality=30)#------------Create Different folder-----------

        start5+=1
        print(start5)
# Out:
# Streaming output truncated to the last 5000 lines.
# 390005
# 390007
# 390009
# 390011
# 390013
# 390015
# 390017
# 390019
# 390021
# 390023
# 390025
# 390027
# 390029
# 390031
# 390033
# 390035
# 390037
# 390039
# 390041
# 390043
# 390045
# 390047
# 390049
# 390051
# 390053
# 390055
# 390057
# 390059
# 390061
# 390063
# 390065
# 390067
# 390069
# 390071
# 390073
# 390075
# 390077
# 390079
# 390081
# 390083
# 390085
# 390087
# 390089
# 390091
# 390093
# 390095
# 390097
# 390099
# 390101
# 390103
# 390105
# 390107
# 390109
# 390111
# 390113
# 390115
# 390117
# 390119
# 390121
# 390123
# 390125
# 390127
# 390129
# 390131
# 390133
# 390135
# 390137
# 390139
# 390141
# 390143
# 390145
# 390147
# 390149
# 390151
# 390153
# 390155
# 390157
# 390159
# 390161
# 390163
# 390165
# 390167
# 390169
# 390171
# 390173
# 390175
# 390177
# 390179
# 390181
# 390183
# 390185
# 390187
# 390189
# 390191
# 390193
# 390195
# 390197
# 390199
# 390201
# 390203
# 390205
# 390207
# 390209
# 390211
# 390213
# ...

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # Storing and Zipping the Images Seperately

# %%
from zipfile import ZipFile 
import zipfile
import os 
  
def get_all_file_paths(directory): 
  
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath) 
  
    # returning all file paths 
    return file_paths         
  
def main(): 
    # path to folder which needs to be zipped 
    directory = 'OverlayDir'
  
    # calling function to get all file paths in the directory 
    file_paths = get_all_file_paths(directory) 
  
    # printing the list of all files to be zipped 
    print('Following files will be zipped:') 
    count=0
    for file_name in file_paths:
        count=count+1 
        print(file_name)

    print ("No. of Files in Dataset")
    print(count)
    # writing files to a zipfile 
    with ZipFile('/content/gdrive/My Drive/EVA4/fg_bg Images/dataset_1_400','a', compression = zipfile.ZIP_DEFLATED) as zip: 
        # writing each file one by one 
        for file in file_paths: 
            zip.write(file) 
  
    print('All files zipped successfully!')         
  
  

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# OverlayDir/BgFgMask/bgfgmask285543.jpg
# OverlayDir/BgFgMask/bgfgmask40453.jpg
# OverlayDir/BgFgMask/bgfgmask107402.jpg
# OverlayDir/BgFgMask/bgfgmask35732.jpg
# OverlayDir/BgFgMask/bgfgmask24118.jpg
# OverlayDir/BgFgMask/bgfgmask278741.jpg
# OverlayDir/BgFgMask/bgfgmask390974.jpg
# OverlayDir/BgFgMask/bgfgmask236033.jpg
# OverlayDir/BgFgMask/bgfgmask314624.jpg
# OverlayDir/BgFgMask/bgfgmask296094.jpg
# OverlayDir/BgFgMask/bgfgmask265280.jpg
# OverlayDir/BgFgMask/bgfgmask28818.jpg
# OverlayDir/BgFgMask/bgfgmask323713.jpg
# OverlayDir/BgFgMask/bgfgmask153699.jpg
# OverlayDir/BgFgMask/bgfgmask196729.jpg
# OverlayDir/BgFgMask/bgfgmask8743.jpg
# OverlayDir/BgFgMask/bgfgmask62376.jpg
# OverlayDir/BgFgMask/bgfgmask69295.jpg
# OverlayDir/BgFgMask/bgfgmask61729.jpg
# OverlayDir/BgFgMask/bgfgmask224916.jpg
# OverlayDir/BgFgMask/bgfgmask131832.jpg
# OverlayDir/BgFgMask/bgfgmask62738.jpg
# OverlayDir/BgFgMask/bgfgmask85580.jpg
# ...

# %% [markdown]
# Submitted by G Uday Kiran and Srilakshmi V
